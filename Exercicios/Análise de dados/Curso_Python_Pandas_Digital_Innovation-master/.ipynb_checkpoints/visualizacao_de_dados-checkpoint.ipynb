# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

print("#Changing column Data to type [int64]\n"
      "#Alterando coluna Data para tipo [int64]")
df["Data"] = df["Data"].view("int64")
print(df.dtypes)
print("\n")

print("#Changing column Data to type [datatime]\n"
      "#Alterando coluna Data para tipo [datetime]")
df["Data"] = pd.to_datetime(df["Data"])
print(df.dtypes)
print("\n")

print("#Creat a new column [Receita] \n"
      "#Criando uma nova columa [Receita]")
df["Receita"] = df["Vendas"].mul(df["Qtde"])
print("\n")

print("#Total revenue per year \n"
      "#Total de receita por ano")
print(df.groupby(df["Data"].dt.year)["Receita"].sum())
print("\n")

#groupby(Python) = Join(SQL)

print("#Create a new column [Ano_Venda] \n"
      "#Criando uma nova coluna [Ano_Venda]")
df["Ano_Venda"] = df["Data"].dt.year
print("\n")

#print(df.sample(5))

print("#Create a new column [Mes_Venda] \n"
      "#Criando uma nova coluna [Mes_Venda]")
df["Mes_Venda"] = df["Data"].dt.month
print(df.sample(5))
print("\n")

print("#Create a new column [Dia_Venda] \n"
      "#Criando uma nova coluna [Dia_Venda]")
df["Dia_Venda"] = df["Data"].dt.day
print(df.sample(5))
print("\n")

#print(df.sample(5))

print("#Date minimum \n"
      "Data mínima")
print(df["Data"].min())
print(df.sample(5))
print("\n")

print("#Showing the diference of days between column [Data] and [Data].min() - Date minimum \n"
      "#Mostrando a diferença de dias entre a coluna [Data] e a data mínima")
df["Diferenca_Dias"] = df["Data"] - df["Data"].min()
print(df.sample(5))
print("\n")

print("#Showing quarter according to date [Data] \n" 
      "#Mostrando o trimestre de acordo com a data")
df["Trimestre_Venda"] = df["Data"].dt.quarter
print(df.sample(5))
print("\n")

# print("#Showing sales in march 2019 \n"
#       "#Mostrando as vendas em março de 2019")
# df["Vendas_Marco_2019"] = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]
# print(df.sample(5))
# print("\n")
# Out:
# #Changing column Data to type [int64]
# #Alterando coluna Data para tipo [int64]
# Cidade     object
# Data        int64
# Vendas    float64
# LojaID      int64
# Qtde        int64
# dtype: object
#
#
# #Changing column Data to type [datatime]
# #Alterando coluna Data para tipo [datetime]
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object
#
#
# #Creat a new column [Receita]
# #Criando uma nova columa [Receita]
#
#
# #Total revenue per year
# #Total de receita por ano
# Data
# 2018     46426.53
# 2019    170682.90
# Name: Receita, dtype: float64
#
#
# #Create a new column [Ano_Venda]
# #Criando uma nova coluna [Ano_Venda]
#
#
# #Create a new column [Mes_Venda]
# #Criando uma nova coluna [Mes_Venda]
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  Mes_Venda
# 36    Salvador 2019-01-01    9.67    1037     1     9.67       2019          1
# 78   Fortaleza 2019-01-01   37.66    1005     2    75.32       2019          1
# 4    Fortaleza 2019-01-01   14.25    1004     6    85.50       2019          1
# 82    Salvador 2019-01-01  207.88    1035     1   207.88       2019          1
# 112  Fortaleza 2019-03-02  133.59     982     1   133.59       2019          3
#
#
# #Create a new column [Dia_Venda]
# #Criando uma nova coluna [Dia_Venda]
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  \
# 45    Salvador 2019-01-01  175.25    1035     3   525.75       2019
# 132  Fortaleza 2019-03-02   17.49     983     5    87.45       2019
# 82    Salvador 2019-01-01  207.88    1035     1   207.88       2019
# 26   Fortaleza 2019-01-01   18.93    1005     2    37.86       2019
# 203   Salvador 2019-01-02   37.75    1035     2    75.50       2019
#
#      Mes_Venda  Dia_Venda
# 45           1          1
# 132          3          2
# 82           1          1
# 26           1          1
# 203          1          2
#
#
# #Date minimum
# Data mínima
# 2018-01-01 00:00:00
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  \
# 95   Fortaleza 2019-01-01   35.28    1002     2    70.56       2019
# 4    Fortaleza 2019-01-01   14.25    1004     6    85.50       2019
# 60    Salvador 2019-01-01   96.01    1034     2   192.02       2019
# 116  Fortaleza 2019-03-02   79.10     982     2   158.20       2019
# 117   Salvador 2019-03-02   39.41    1034     1    39.41       2019
#
#      Mes_Venda  Dia_Venda
# 95           1          1
# 4            1          1
# 60           1          1
# 116          3          2
# 117          3          2
#
#
# #Showing the diference of days between column [Data] and [Data].min() - Date minimum
# #Mostrando a diferença de dias entre a coluna [Data] e a data mínima
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  \
# 84   Fortaleza 2019-01-01  147.46    1003     6   884.76       2019
# 62     Aracaju 2018-01-01   28.66    1520     3    85.98       2018
# 54    Salvador 2019-01-01   46.54    1037     3   139.62       2019
# 102  Fortaleza 2019-01-01   13.99    1004     3    41.97       2019
# 59     Aracaju 2018-01-01   15.07    1523     7   105.49       2018
#
#      Mes_Venda  Dia_Venda Diferenca_Dias
# 84           1          1       365 days
# 62           1          1         0 days
# 54           1          1       365 days
# 102          1          1       365 days
# 59           1          1         0 days
#
#
# #Showing quarter according to date [Data]
# #Mostrando o trimestre de acordo com a data
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano_Venda  \
# 17      Recife 2019-02-14  142.45     981     3   427.35       2019
# 110   Salvador 2019-03-02  185.93    1036     3   557.79       2019
# 148     Recife 2019-03-08     NaN     983     8      NaN       2019
# 84   Fortaleza 2019-01-01  147.46    1003     6   884.76       2019
# 64   Fortaleza 2019-01-01  110.31    1005     4   441.24       2019
#
#      Mes_Venda  Dia_Venda Diferenca_Dias  Trimestre_Venda
# 17           2         14       409 days                1
# 110          3          2       425 days                1
# 148          3          8       431 days                1
# 84           1          1       365 days                1
# 64           1          1       365 days                1

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

print("#Showing the number of row in the column [LojaID] \n"
      "#Mostrando a quantidade de linha na coluna [LojaID]")

print(df["LojaID"].value_counts(ascending=True).plot.bar())#Vertical
# Out:
# #Showing the number of row in the column [LojaID]
# #Mostrando a quantidade de linha na coluna [LojaID]
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

print(df["LojaID"].value_counts(ascending=False).plot.barh())#Horizontal
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

df["Receita"] = df["Vendas"].mul(df["Qtde"])
print("\n")

print(df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie())
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

print(df["Cidade"].value_counts())
print("\n")

plt.style.use("default")

print("Withdout color=default and style=default")
print(df["Cidade"].value_counts().plot.bar(title="Total sales by city"))
plt.xlabel("Cidade")
plt.ylabel("Total de vendas")
print("\n")
# Out:
# Fortaleza    284
# Salvador     240
# Recife       149
# Aracaju      130
# Name: Cidade, dtype: int64
#
#
# Withdout color=default and style=default
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

print(df["Cidade"].value_counts())
print("\n")

plt.style.use("default")

print("With color=red and style=default")
print(df["Cidade"].value_counts().plot.bar(title="Total sales by city", color="red"))
plt.xlabel("Cidade")
plt.ylabel("Total de vendas")
print("\n")
# Out:
# Fortaleza    284
# Salvador     240
# Recife       149
# Aracaju      130
# Name: Cidade, dtype: int64
#
#
# With color=red and style=default
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
plt.style.use("ggplot")

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

df["Data"] = pd.to_datetime(df["Data"])

#https://matplotlib.org/stable/gallery/style_sheets/ggplot.html
plt.style.use("ggplot")

print("#Create a new column [Mes_Venda] \n"
      "#Criando uma nova coluna [Mes_Venda]")
df["Mes_Venda"] = df["Data"].dt.month
print(df.sample(5))
print("\n")

print(df.groupby(df["Mes_Venda"])["Qtde"].sum().plot(title = "Total de produtos vendidos x Mês"))
plt.xlabel("Mês")
plt.ylabel("Total de produtos vendidos")
plt.legend();
print("\n")

print(df.groupby(df["Mes_Venda"])["Qtde"].sum())
print("\n")

df["Ano_Venda"] = df["Data"].dt.year
# Out:
# #Create a new column [Mes_Venda]
# #Criando uma nova coluna [Mes_Venda]
#        Cidade       Data  Vendas  LojaID  Qtde  Mes_Venda
# 76     Recife 2019-01-01   17.86     980     5          1
# 82   Salvador 2019-01-01  207.88    1035     1          1
# 96  Fortaleza 2019-01-01   23.31    1004     4          1
# 44    Aracaju 2018-01-01   11.42    1520     5          1
# 31   Salvador 2019-01-01  202.25    1035     2          1
#
#
# AxesSubplot(0.125,0.11;0.775x0.77)
#
#
# Mes_Venda
# 1    2232
# 2     108
# 3     633
# Name: Qtde, dtype: int64

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

df["Data"] = pd.to_datetime(df["Data"])

#https://matplotlib.org/stable/gallery/style_sheets/ggplot.html
plt.style.use("ggplot")

print("#Create a new column [Mes_Venda] \n"
      "#Criando uma nova coluna [Mes_Venda]")
df["Mes_Venda"] = df["Data"].dt.month
print(df.sample(5))
print("\n")

df["Ano_Venda"] = df["Data"].dt.year

print("Showing all sales in 2019")
df_2019 = df[df["Ano_Venda"] == 2019]
print("\n")

print(df_2019.groupby(df_2019["Mes_Venda"])["Qtde"].sum().plot(marker = "v"))
plt.xlabel("Mês")
plt.ylabel("Total de produtos vendidos")
plt.legend();
print("\n")
# Out:
# #Create a new column [Mes_Venda]
# #Criando uma nova coluna [Mes_Venda]
#         Cidade       Data  Vendas  LojaID  Qtde  Mes_Venda
# 67      Recife 2019-01-01  179.52     983     5          1
# 26   Fortaleza 2019-01-01   18.93    1005     2          1
# 111  Fortaleza 2019-03-02    8.00     981     3          3
# 121   Salvador 2019-03-02  100.70    1037     3          3
# 32   Fortaleza 2019-01-01   43.33    1004     4          1
#
#
# Showing all sales in 2019
#
#
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

df["Data"] = pd.to_datetime(df["Data"])

#https://matplotlib.org/stable/gallery/style_sheets/ggplot.html
plt.style.use("ggplot")

plt.hist(df["Qtde"], color="orangered")
# Out:
# (array([147., 136., 170.,  87.,  75.,  83.,  43.,  42.,  14.,   6.]),
#  array([ 1. ,  1.9,  2.8,  3.7,  4.6,  5.5,  6.4,  7.3,  8.2,  9.1, 10. ]),
#  <BarContainer object of 10 artists>)

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

df["Data"] = pd.to_datetime(df["Data"])

#https://matplotlib.org/stable/gallery/style_sheets/ggplot.html
plt.style.use("ggplot")

df["Receita"] = df["Vendas"].mul(df["Qtde"])
print("\n")

print("#Create a new column [Mes_Venda] \n"
      "#Criando uma nova coluna [Mes_Venda]")
df["Mes_Venda"] = df["Data"].dt.month
print(df.sample(5))
print("\n")

df["Dia_Venda"] = df["Data"].dt.day
df["Ano_Venda"] = df["Data"].dt.year

print("Showing all sales in 2019")
df_2019 = df[df["Ano_Venda"] == 2019]
print("\n")

plt.scatter(x=df_2019["Dia_Venda"], y=df_2019["Receita"]);
# Out:
# #Create a new column [Mes_Venda]
# #Criando uma nova coluna [Mes_Venda]
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Mes_Venda
# 61   Fortaleza 2019-01-01   37.41    1002     5   187.05          1
# 89   Fortaleza 2019-01-01    7.19    1004     5    35.95          1
# 156   Salvador 2019-01-02   36.14    1037     3   108.42          1
# 29    Salvador 2019-01-01    9.27    1034     1     9.27          1
# 100  Fortaleza 2019-01-01   18.58    1003     1    18.58          1
#
#
# Showing all sales in 2019

# %%
#Step ONE - Import library of pandas with alias (pd)
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

#Step TWO - Declarar a variável file_name para receber o diretório(Copy path) do arquivo excel
# Declarar variável df(Data Frame) para receber os dados variável file_name
file_name1 = "datasets/Aracaju.xlsx"
file_name2 = "datasets/Fortaleza.xlsx"
file_name3 = "datasets/Fortaleza.xlsx"
file_name4 = "datasets/Recife.xlsx"
file_name5 = "datasets/Salvador.xlsx"

df1 = pd.read_excel(file_name1, engine="openpyxl")
df2 = pd.read_excel(file_name2, engine="openpyxl")
df3 = pd.read_excel(file_name3, engine="openpyxl")
df4 = pd.read_excel(file_name4, engine="openpyxl")
df5 = pd.read_excel(file_name5, engine="openpyxl")

df = pd.concat([df1, df2, df3, df4, df5])#Concatenate all data frames to one data frame(df)

df["Data"] = pd.to_datetime(df["Data"])

#https://matplotlib.org/stable/gallery/style_sheets/ggplot.html
plt.style.use("ggplot")

print("#Create a new column [Mes_Venda] \n"
      "#Criando uma nova coluna [Mes_Venda]")
df["Mes_Venda"] = df["Data"].dt.month
print(df.sample(5))
print("\n")

df["Ano_Venda"] = df["Data"].dt.year

print("Showing all sales in 2019")
df_2019 = df[df["Ano_Venda"] == 2019]
print("\n")

print(df_2019.groupby(df_2019["Mes_Venda"])["Qtde"].sum().plot(marker = "v"))
plt.xlabel("Mês")
plt.ylabel("Total de produtos vendidos")
plt.legend();
plt.savefig("Grafico Qtde x Mês.png")
# Out:
# #Create a new column [Mes_Venda]
# #Criando uma nova coluna [Mes_Venda]
#         Cidade       Data  Vendas  LojaID  Qtde  Mes_Venda
# 102     Recife 2019-01-01   96.50     982     7          1
# 135   Salvador 2019-03-02    9.95    1037     3          3
# 70      Recife 2019-01-01   20.40     983     7          1
# 70   Fortaleza 2019-01-01   79.57    1002     5          1
# 113    Aracaju 2018-01-01   23.05    1521     9          1
#
#
# Showing all sales in 2019
#
#
# AxesSubplot(0.125,0.11;0.775x0.77)
